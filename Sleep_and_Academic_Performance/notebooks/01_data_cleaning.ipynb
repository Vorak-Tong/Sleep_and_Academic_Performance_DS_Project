# %% [markdown]
# **1. Load Dataset**

# %%
import pandas as pd

df = pd.read_csv("../data/raw/student_lifestyle_dataset.csv")

df.head()
# Out:
#    Student_ID  Study_Hours_Per_Day  Extracurricular_Hours_Per_Day  \
# 0           1                  6.9                            3.8
# 1           2                  5.3                            3.5
# 2           3                  5.1                            3.9
# 3           4                  6.5                            2.1
# 4           5                  8.1                            0.6
#
#    Sleep_Hours_Per_Day  Social_Hours_Per_Day  Physical_Activity_Hours_Per_Day  \
# 0                  8.7                   2.8                              1.8
# 1                  8.0                   4.2                              3.0
# 2                  9.2                   1.2                              4.6
# 3                  7.2                   1.7                              6.5
# 4                  6.5                   2.2                              6.6
#
#     GPA Stress_Level
# 0  2.99     Moderate
# 1  2.75          Low
# 2  2.67          Low
# ...

# %% [markdown]
# **2. Check shape of dataset**

# %%
df.shape
# Out:
# (2000, 8)

# %% [markdown]
# **3. Remove unnecessary column**

# %%
df = df.drop(columns=["Student_ID"])

# %% [markdown]
# **4. Check data type**

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 7 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Study_Hours_Per_Day              2000 non-null   float64
#  1   Extracurricular_Hours_Per_Day    2000 non-null   float64
#  2   Sleep_Hours_Per_Day              2000 non-null   float64
#  3   Social_Hours_Per_Day             2000 non-null   float64
#  4   Physical_Activity_Hours_Per_Day  2000 non-null   float64
#  5   GPA                              2000 non-null   float64
#  6   Stress_Level                     2000 non-null   str
# dtypes: float64(6), str(1)
# memory usage: 109.5 KB

# %% [markdown]
# **5. Check missng values**

# %%
df.isnull().sum()
# Out:
# Study_Hours_Per_Day                0
# Extracurricular_Hours_Per_Day      0
# Sleep_Hours_Per_Day                0
# Social_Hours_Per_Day               0
# Physical_Activity_Hours_Per_Day    0
# GPA                                0
# Stress_Level                       0
# dtype: int64

# %% [markdown]
# **6. Check duplicate rows**

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **7. Check basic statistic**

# %%
df.describe()
# Out:
#        Study_Hours_Per_Day  Extracurricular_Hours_Per_Day  \
# count          2000.000000                    2000.000000
# mean              7.475800                       1.990100
# std               1.423888                       1.155855
# min               5.000000                       0.000000
# 25%               6.300000                       1.000000
# 50%               7.400000                       2.000000
# 75%               8.700000                       3.000000
# max              10.000000                       4.000000
#
#        Sleep_Hours_Per_Day  Social_Hours_Per_Day  \
# count          2000.000000           2000.000000
# mean              7.501250              2.704550
# std               1.460949              1.688514
# min               5.000000              0.000000
# 25%               6.200000              1.200000
# 50%               7.500000              2.600000
# 75%               8.800000              4.100000
# ...

# %% [markdown]
# **8. Check unique value for categorical columns**

# %%
df["Stress_Level"].unique()
# Out:
# <StringArray>
# ['Moderate', 'Low', 'High']
# Length: 3, dtype: str

# %% [markdown]
# **9. Save cleaned dataset**

# %%
df.to_csv("../data/processed/student_lifestyle_cleaned.csv", index=False)
